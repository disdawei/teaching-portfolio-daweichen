# %% [markdown]
# # MGS3101 — Assignment 3
#
# - *Topic:* Data Wrangling & Statistical Inference
# - *Deadline:* **14 November 2025, Friday, 23:59 (Beijing Time)**
#
# ### **Deliverables**
# - Write your Python codes in code cells and your answers or explanations in Markdown cells below each question. You may insert extra cells for clarity or additional analysis if needed.
# - When finishing, rename your notebook as: `MGS3101_A3_YourName.ipynb`, and submit it to Canvas before the deadline.
#
# > **Note:**
# > This assignment was prepared with ChatGPT-5. At the end of your notebook, please briefly state **whether and how** you used AI tools in completing the work.

# %% [markdown]
# ### Dataset Description
#
# The dataset `wku_cafe_transactions_messy.csv` records individual customer orders from WKU Café. Each row represents one transaction and contains key information about the customer, order channel, and amount paid.
#
# | **Variable** | **Type** | **Description** |
# |---------------|-----------|-----------------|
# | `order_id` | Integer | Unique identifier for each order. |
# | `order_date` | Date | Date when the order was placed (YYYY-MM-DD). |
# | `customer_id` | Integer | Unique customer identifier, used for joins or aggregations. |
# | `channel` | Categorical | Ordering channel: `"In-Store"`, `"App"`, `"Delivery"` |
# | `membership_tier` | Categorical | Customer membership level: `"Guest"`, `"Silver"`, `"Gold"`, or `"Platinum"`. |
# | `total_rmb` | Numeric | Final amount paid for the order (in RMB), after discounts and including any tip. |
# | `tip_rmb` | Numeric | Tip amount (in RMB). |
#
# > **Note:** The dataset intentionally includes some missing values, duplicates, data-type inconsistencies, and outliers to support practice in data cleaning, transformation, and statistical inference.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 0 — Load & Preview the Dataset
#
# **(0a):** Import the necessary modules: `pandas`, `numpy`, `matplotlib.pyplot`.

# %% [markdown]
# **(0b):** Load the dataset `wku_cafe_transactions_messy.csv` into a DataFrame named `data`, and display the **first few rows** using `head()`.

# %% [markdown]
# **(0c):** Use `info()` to display the dataset's **basic information**, including column names, data types, and non-null counts.

# %% [markdown]
# <u>**(0d):**</u> Based on the output of `info()`:
# - What is the total number of observations (orders/transactions) in the dataset?
# - Which variables contain missing values?
# - How many missing observations does each of these variables have?

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# **(0e):** Display the **summary statistics** for all numerical variables using `describe()`.

# %% [markdown]
# **(0f):** Based on the output of `describe()`, what do the *mean*, *standard deviation*, and *range* of `total_rmb` suggest about the **customer spending behavior** at WKU Café?

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 1 — Identify & Remove Duplicates
#
# **(1a):** **Select and display** the duplicate rows (**full-row duplicates**), and **report the count**.

# %% [markdown]
# **(1b):** Remove duplicate row from the dataset, keeping only the **first** occurrence, and save the cleaned result as `df`.

# %% [markdown]
# **(1c):** Explain in 1–2 sentences **how** duplicates could arise in data and **how** they affect analysis.

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2 — Identify & Impute Missing Values
#
# > **Note:** Some functions **return a modified copy** of the DataFrame, while others **change it directly**. Pay attention to whether you need to **assign results to a new variable** or **modify the existing DataFrame in place**.

# %% [markdown]
# **(2a):** Count and display the number of missing values for each variable of the new dataset `df`.

# %% [markdown]
# **(2b):** Find and display only the rows where `tip_rmb` is missing in the new dataset `df`.

# %% [markdown]
# **(2c):** For the numeric variable `tip_rmb` in the new dataset `df`:
# - Before imputing, create a new indicator column named `is_tip_imputed` that equals `1` if the value was imputed (or missing), otherwise `0`.
# - Creat a new column named `tip_imputed_mean` by imputing the missing values in `tip_rmb` with the **median** of the existing (non-missing) values.

# %% [markdown]
# **(2d):** For the categorical variable `membership_tier` in the new dataset `df`:
# - Create a new indicator column named `is_tier_imputed` that equals `1` if the value was imputed (or missing), otherwise `0`.
# - Creat a new column named `tier_imputed_mode` by imputing the missing values in `membership_tier` with the **mode** of the existing values.

# %% [markdown]
# **(2e):** Briefly justify your imputation choices (1–2 sentences each):
# - Why is the **median** suitable for `tip_rmb`?
# - Why is the **mode** suitable for `membership_tier`?

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3 — Normalization & Scaling
# For the numeric variables `total_rmb` in the dataset `df`:
#
# **(4a):** Create a new column `total_minmax` by applying **Min–Max normalization** to scale values to the range **[0, 1]**.
# *(Hint: use the formula (x − min) / (max − min); do not use external libraries.)*

# %% [markdown]
# **(4b):** Create a new column `total_zscore` by applying **standardization** (z-score scaling) using the formula **(x − mean) / std** (no external libararies).

# %% [markdown]
# **(4c):** Briefly explain in 1–2 sentences: When would you prefer to use **Min–Max normalization**, and when would you prefer **standardization (z-score)**?

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 4 — Interval Estimation
# > **Goal:** Estimate population parameters (mean and proportion) using sample data and confidence intervals.

# %% [markdown]
# **(4a):** Construct a **95% confidence interval (CI)** for the **mean** of `total_rmb`.
# - Assume the **population standard deviation is unknown**, so use the **t-distribution**.
# - **Hint:** You can find the t-score or t-critical vale in Python using:
#   ```python
#   from scipy.stats import t
#   t_crit = t.ppf(1 - 0.05/2, df=n-1)

# %% [markdown]
# **(4b):** Construct a **95% confidence interval (CI)** for the **proportion** of orders placed through the **App** channel.
# - **Hint:** Use the code below to find the z-critical value:
# ```python
# from scipy.stats import norm
# z_crit = norm.ppf(1 - 0.05/2)  # approximately 1.96 for 95% CI

# %% [markdown]
# **(4c):** Interpret your results in plain language (1–2 sentences each):
# - What does the confidence interval for the mean spending (`total_rmb`) tell you about average customer spending at WKU Café?
# - What does the confidence interval for the **App order proportion** tell you about customer ordering behavior?

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 5 — Hypothesis Testing
# > **Goal:** Use sample data to test claims about population means and proportions.
# >
# 1. **One-sample t-test**: Is the mean `total_rmb` **greater than 42 RMB**? (α = 0.05, **one-sided**).
#    - State H₀ and H₁; compute test statistic and p-value; conclude.
# 2. **Two-sample test (Welch’s t)**: Do **Delivery** orders have a **higher mean** `total_rmb` than **In-Store**? (one-sided, α = 0.05).
# 3. **Proportion z-test**: Is the share of **App** orders **different from** 30%? (two-sided, α = 0.05).

# %% [markdown]
# **(5a): One-Sample t-Test**
# - Test whether the average spending (`total_rmb`) is **greater than 42 RMB** at the **5% significance level** (α = 0.05, one-sided test).
# - Clearly state your hypotheses:
#     - H₀: μ = 42
#     - H₁: μ > 42
# - Compute the **test statistic (t)** and **p-value**, and then draw a conclusion.
# > **Hint:** Use the function `ttest_1samp` from the module `scipy.stats`

# %% [markdown]
# **(5b):** In 1–2 sentences, state whether you reject or fail to reject the null hypothesis (H₀: μ = 42). Then briefly explain what this result means in the context of WKU Café (e.g., about customer spending or order patterns).

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# **(5c): Two-Sample t-Test (Welch’s Test)**
# - Test whether **Delivery orders** have a higher mean `total_rmb` than **In-Store orders** (α = 0.05, one-sided test).
# - Clearly state your hypotheses:
#     - H₀: μ₁ = μ₂
#     - H₁: μ₁ > μ₂ (Delivery > In-Store)
# - Use Welch’s t-test (assumes unequal variances).
# > **Hint:** Use the function `ttest_ind` from the module `scipy.stats`

# %% [markdown]
# **(5d):** In 1–2 sentences, state whether you reject or fail to reject the null hypothesis (H₀: μ₁ = μ₂). Then briefly explain what this result means in the context of WKU Café (e.g., about customer spending or order patterns).

# %% [markdown]
# <u>**Your Answers:**</u>

# %% [markdown]
# ## AI Use Disclousre
# Please state whether you used any AI tools (e.g., ChatGPT, Copilot) and briefly describe how they were used to complete this assignment.
