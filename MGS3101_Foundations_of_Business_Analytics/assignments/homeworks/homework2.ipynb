# %% [markdown]
# # MGS3101 — Assignment 2
#
# - **Topic:** Descriptive Statistics & Data Visualization
# - **Deadline:** 18 October 2025, 23:59 (Beijing Time)
#
# ---
#
# ### **Deliverables**
# - Write your **Python codes** in **code cells** and your **answers or explanations** in **Markdown cells** below each question (and before the next question).
# - You may **add extra cells** as needed for clarity or additional analysis.
# - After completing the assignment, **rename and save** this notebook as:
#   `MGS3101_A2_YourName.ipynb`
# - Upload your final file to **Canvas** before the deadline.
#
# > **Note:**
# > ChatGPT5 is used to prepare this assignment. Please indicate whether and how you use AI to finish this assignement at the end of the notebook.

# %% [markdown]
# ### **Dataset (provided on Canvas)**
#
# **File:** `wkucafe_transactions.csv`
#
# The dataset contains *2,500 transaction records* from **WKU Café**, which operates three on-campus stores. It captures two weeks of daily sales and includes details on **order timing, sales channels, membership tiers, coupon usage, basket composition, spending, wait times,** and **customer satisfaction**.
#
# The data are designed to support **descriptive analytics** and **data visualization** exercises — helping you explore customer spending behavior, operational performance, and potential data quality issues (e.g., outliers such as unusually large or negative transaction values).
#
#
# | **Variable** | **Type** | **Description** |
# |---------------|-----------|-----------------|
# | `transaction_id` | string | Unique order ID |
# | `datetime_local` | datetime | Local order timestamp (Beijing Time) |
# | `store_id` | categorical | Store identifier: WZ01, WZ02, WZ03 |
# | `channel` | categorical | Order channel: In-Store, App, Delivery |
# | `membership_tier` | categorical | Customer membership level: None, Silver, Gold |
# | `coupon_used` | 0/1 | 1 if a coupon was applied |
# | `items_count` | integer | Number of items in the basket |
# | `avg_item_price_rmb` | float | Average item price within the basket (RMB) |
# | `basket_value_rmb` | float | Total order value (may include anomalies or refunds) |
# | `wait_time_sec` | integer | Wait time in seconds from order to fulfillment |
# | `satisfaction_1to5` | integer | Customer satisfaction rating (1 = lowest, 5 = highest) |
#
#
# >  **Note:**
# > - Some extreme values (e.g., corporate orders, key-in errors, or refunds) are intentionally included in this dataset.
# > - How you handle these values should depend on your analytical purpose — avoid removing data without proper justification.
# > - At this stage, **you do not need to handle them**. We will cover this topic (data cleaning) **after the midterm exam**.

# %% [markdown]
# ## 0. Setup
# - Import the necessary modules, such as `pandas`, `numpy`, `matplotlib.pyplot`.
# - Load the provided dataset (`wkucafe_transactions.csv`) into a DataFrame and assign it to a variable named `data`.
# - Display the **first few rows** of `data` to confirm that it has been loaded correctly.

# %% [markdown]
# ## 1. Descriptive Statistics
#
# **(1a) Core KPIs Analysis**
# - Compute descriptive statistics for the key performance indicators (KPIs): `basket_value_rmb`, `items_count`, and `wait_time_sec`.
#   Include the following measures: **mean**, **median**, **standard deviation**, **minimum**, **maximum**, and **skewness**.
#   *(Write your code in the **Code cells** below.)*
#
# - For **each KPI**, decide which measure of central tendency (**mean** or **median**) is more appropriate to report.
#   Justify your choice in **1–2 sentences** based on the variable’s distribution shape (e.g., skewness).
#   *(Write your explanation in the **Markdown cells** after computing all the statistics.)*

# %% [markdown]
# **(1b) Segment Comparisons**
#
# Compare `basket_value_rmb` across two dimensions: **channel** and **membership_tier**.
# *(Hint: Use the `groupby()` function or, first select and then calculate statistics separately for each group.)*
#
# - For each group, compute **2–3 relevant statistical measures** (e.g., median and IQR, or mean and standard deviation).
#   *(Write your code in the **Code cells** below.)*
# - **Decide** which measures are most appropriate and **justify** your choice based on the data distribution or business context. (Write your explanation in the Markdown cells after computing all the statistics.)
# - In **3–4 sentences**, interpret the results and discuss their **business implications**. For example, you might observe that *“App orders tend to be smaller but occur more frequently.”* Focus on what these statistics reveal about **customer behavior**, **spending patterns**, or **operational performance**. *(Write your explanation in the Markdown cells.)*

# %% [markdown]
# ## 2. Visualizations
#
# - The manager would like to compare **revenue (`basket_value_rmb`)** across different **channels**.
#   Create an appropriate chart for this comparison (e.g., the x-axis represents channels, and the y-axis shows either the **total** or **average** revenue — depending on the insight you wish to emphasize).   *(Write your code in the **Code cells** below.)*
#   *(Hint: Refer to **(1b)** for guidance on computing statistical measures for different groups.)*
# - In **2–3 sentences**, describe the **insights** obtained from this visualization. Focus on what the chart reveals about **sales performance**, **customer behavior**, or **channel effectiveness**. *(Write your explanation in the Markdown cells after creating the plot.)*

# %% [markdown]
# ## 3. Outlier Detection
# - Detect outliers in `basket_value_rmb` with **Z-score** (|z|>3) and **IQR rule**. (Write your code in the Code cells below.)
# - Use a **boxplot** to visualize. (Write your code in the Code cells below.)
# - Compare counts from the two rules and list overlapping vs. unique outliers. *(Write your answers in the Markdown cells after computing all the statistics and visualization.)*

# %% [markdown]
# ## AI Use Declaration
