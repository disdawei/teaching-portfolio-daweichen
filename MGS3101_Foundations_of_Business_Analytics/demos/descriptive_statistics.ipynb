# %% [markdown]
# # Demo: Descriptive Statistics with Python
#
# **Dataset:** `students_scores.csv`
#
# **Purpose:** Apply descriptive statistics to a realistic dataset and practice outlier detection using both numeric rules and visual inspection.
#
# > This notebook contains **instructions and questions only**. You will create your own code cells underneath each section to complete the tasks.

# %% [markdown]
# ## Getting Started
#
# 1. Download the dataset file `students_scores.csv` from Canvas.
# 2. Create a new code cell **below this one** to load the CSV into a pandas DataFrame named `df`.
# 3. Display the first few rows so you can see the columns.
#
# **Columns available:**
# `StudentID`, `Gender`, `StudyHours`, `Absences`, `MathScore`, `EnglishScore`, `Height_cm`

# %% [markdown]
# ---
#
# ## Part 1: Core Descriptive Statistics
#
# ### A. One Variable at a Time
# Choose **MathScore** first.
#
# 1. Compute and report: **mean, median, mode**.
# 2. Compute and report **min, max, range**.
# 3. Compute and report **variance, standard deviation**.
# 4. Compute **Q1 (25%), Q3 (75%)**, and **IQR = Q3 − Q1**.
# 5. Compute **skewness** and **kurtosis**.
#
# (Write your Python code in the code cells provided below. You may insert additional cells if needed.)

# %% [markdown]
# **Questions:**
# - (1-A-1) Which measure of center is most appropriate if the data are skewed? Why?
# - (1-A-2) What does the standard deviation tell you about the spread of MathScore?
# - (1-A-3) Do skewness and kurtosis suggest any departures from normality?

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(1-A-1):**
# this is my answer vvvvvv

# %% [markdown]
# **(1-A-2):**

# %% [markdown]
# **(1-A-3):**

# %% [markdown]
# ### B. Whole DataFrame at Once
#
# Using the **entire DataFrame `df`**:
#
# 1. Produce a table of summary statistics for all numeric columns (count, mean, std, min, quartiles, max).
# 2. Produce a **variance** table for all numeric columns.
# 3. Produce a **standard deviation** table for all numeric columns.
# 4. Produce a **covariance matrix** for all numeric columns.
# 5. Produce a **correlation matrix** for all numeric columns.
#
# (Write your Python code in the code cells provided below. You may insert additional cells if needed.)

# %% [markdown]
# **Questions:**
# - (1-B-1) Which variable has the **largest variability**?
# - (1-B-2) Which two variables show the **strongest positive correlation**? Does this make sense substantively?
# - (1-B-3) Are there any pairs with **negative correlation**? Interpret one example in context.

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(1-B-1):**

# %% [markdown]
# **(1-B-2):**

# %% [markdown]
# **(1-B-3):**

# %% [markdown]
# ### C. Brief Interpretation (Mini Task 1)
#
# - In 2–4 sentences, summarize what you learned about the center, spread, and relationships among variables in this dataset.

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(1-C):**

# %% [markdown]
# ---
#
# ## Part 2: Outlier Detection (Rules + Visuals)
#
# The dataset contains **deliberate outliers** (e.g., unusual low **MathScore**, extreme **Height_cm**). Your job is to **identify** and **justify** whether they are outliers.
#
# ### A. Z‑Score Rule
# For **MathScore** and **Height_cm**:
#
# 1. Compute the **z‑score** for each observation.
# 2. Flag any values with **|z| > 3**.
# 3. Count how many potential outliers you found for each variable.
#
# (Write your Python code in the code cells provided below. You may insert additional cells if needed.)

# %% [markdown]
# **Questions:**
# - (2-A-1) Which observations are flagged by the z‑score rule?
# - (2-A-2) Are these values plausible or likely errors? Explain.

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(2-A-1):**

# %% [markdown]
# **(2-A-2):**

# %% [markdown]
# ### B. IQR Rule
# For **MathScore** and **Height_cm**:
#
# 1. Compute **Q1**, **Q3**, and **IQR = Q3 − Q1**.
# 2. Compute **lower fence = Q1 − 1.5 × IQR** and **upper fence = Q3 + 1.5 × IQR**.
# 3. Flag any values **outside** the fences as outliers.
# 4. (Optional) Also compute **3 × IQR** fences to flag **extreme outliers**.
#
# (Write your Python code in the code cells provided below. You may insert additional cells if needed.)

# %% [markdown]
# **Questions:**
# - (2-B-1) Which observations are flagged by the IQR rule?
# - (2-B-2) Do the IQR results agree with the z‑score results? If not, why might they differ?

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(2-B-1):**

# %% [markdown]
# **(2-B-2):**

# %% [markdown]
# ### C. Visual Inspection
# Create the following plots:
#
# 1. **Histogram** for **MathScore** and **Height_cm** (choose sensible bin sizes).
# 2. **Boxplot** for **MathScore** and **Height_cm**.
#
# (Write your Python code in the code cells provided below. You may insert additional cells if needed.)

# %% [markdown]
# **Questions:**
# - (2-C-1) What stands out in each histogram?
# - (2-C-2) Do the boxplots clearly show the outliers?
# - (2-C-3) How do your visual findings compare with the z‑score and IQR flags?

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(2-C-1):**

# %% [markdown]
# **(2-C-2):**

# %% [markdown]
# **(2-C-3):**

# %% [markdown]
# ### D. Decision & Justification
#
# For each flagged outlier (by any method), decide whether to: **keep**, **correct**, or **remove** it.
#
# **Questions:**
# - (2-D-1) Which route did you choose for each outlier, and **why**?
# - (2-D-2) How might each choice affect the **mean** and **standard deviation** of the variable?
# - (2-D-3) If this were a real business analysis, what additional information would you seek before deciding?

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(2-D-1):**

# %% [markdown]
# **(2-D-2):**

# %% [markdown]
# **(2-D-3):**

# %% [markdown]
# ---
#
# ## Wrap‑Up Reflection
#
#
# - (R-1) What is one insight you learned about **descriptive statistics** from this dataset?
# - (R-2) Why is it important to use **both** numeric measures and **visual** tools?
# - (R-3) What questions would you investigate next with this data (e.g., modeling, prediction, segmentation)?

# %% [markdown]
# **Answers:**
# (Write your answers in the markdown cells provided below. You may add more markdown cells if needed.)

# %% [markdown]
# **(R-1):**

# %% [markdown]
# **(R-2):**

# %% [markdown]
# **(R-3):**
