# %% [markdown]
# # Demo: Pandas Basics

# %% [markdown]
# ## Part 1: Load & Prep Dataset

# %% [markdown]
# Instructions:
# 1. Download "ml-100k.zip" from Canvas (datasets module)
# 2. Unzip and read the "README" file (see description of u.data)
# 3. Place "u.data" file and the working jupyter notebook within the **same folder** (or upload via Jupyter file browser)
# 4. In Jupyter Notebook:
#    * Use pd.read_csv() to load "u.data"
#    * Set column names: 'user id', 'item id', 'rating', 'timestamp'
#    * Save as a .csv file

# %% [markdown]
# ### 1-1 Loading the Rating Data

# %%
# Save the above DataFrame as a CSV file named 'rating.csv'
# The file will be stored in the same folder as this notebook and the "u.data" file

# %% [markdown]
# ### 1-2 Loading the Item Data

# %% [markdown]
# Next, upload the **'u.item'** file.
# Make sure it is in the same folder; otherwise, adjust the file path accordingly

# %%
# Save the above DataFrame as a CSV file named 'item.csv' in the same folder

# %% [markdown]
# ## Part 2: Practicing DataFrame Basics

# %% [markdown]
# Create a DataFrame with the Following Columns:
# * “name”: ['Zhangsan', 'Lisi', 'Wangwu', 'Zhaoliu']
# * “age”: [20 , 19, 21, 20]
# * “score”: [78 , 89, 55, 61]
#
# Try the Following Operations:
# * Rename the column “score” to “final_score"
# * Drop the “age” column
# * Display only “name” column
# * Display “name” and “final_score” columns together
# * Show only students with “final_score” is greater than 70
# * Add a new column: “bonus_score” whose values are: final_score + 5
# * Add a new column: “passed” (True if final_score >= 60, False otherwise)

# %% [markdown]
# ### 2-1 Rename the column 'score' to 'final_score'

# %%
# Here, we reassign the output of the "rename" function back to the variable df that we defined earlier.

# %% [markdown]
# ### 2-2 Drop the 'age' column

# %% [markdown]
# What is `df` now?
# The last operation [10] returned a **new** DataFrame and did not modify the original object assigned to `df`.

# %% [markdown]
# ### 2-3 Display only 'name' column

# %% [markdown]
# ### 2-4 Display 'name' and 'final_score' columns together

# %% [markdown]
# **Note: Compare II-3 and II-4**
# * When selecting multiple columns, place their names inside a list `[ ]` and pass it to `df[ ]`. That is why you see `df[[ ]]`.
# * For a single column, `df['name']` and `df[['name']]` both work. The difference is that the first returns a **Series**, while the second returns a **DataFrame**.

# %% [markdown]
# ### 2-5 Show only students with **'final_score'** is greater than 70

# %% [markdown]
# **Think:** what is df now?

# %% [markdown]
# **Multiple Conditions**
# * Display students whose `final_score` is greater than 70 **and** whose `age` is at least 20.
# * Combine conditions with `&`. Each condition must be inside parentheses, e.g. `( ) & ( )`, then pass it into `df[ ]` for selection.

# %% [markdown]
# ### 2-6 Add a new column: **'bonus_score'** whose values are: final_score + 5

# %% [markdown]
# **Note:** The assginment operator **=** is used here. It updates the original DataFrame by adding a new column, 'bonus_score'

# %% [markdown]
# ### 2-7 Add a new column: 'passed' (True if final_score >= 60, False otherwise)

# %% [markdown]
# **Think:** what does 'df['final_score'] >= 60' return?
